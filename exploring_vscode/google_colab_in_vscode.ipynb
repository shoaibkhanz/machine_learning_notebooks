# %% [markdown]
# <a href="https://colab.research.google.com/github/shoaibkhanz/machine_learning_notebooks/blob/main/google_colab_in_vscode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install colabcode
# Out:
# ...
#      |████████████████████████████████| 8.3 MB 5.0 MB/s
# ...
#      |████████████████████████████████| 745 kB 27.6 MB/s
# ...
#      |████████████████████████████████| 45 kB 1.8 MB/s
# ...
#      |████████████████████████████████| 58 kB 2.9 MB/s
# ...
#      |████████████████████████████████| 428 kB 34.9 MB/s
# ...
#      |████████████████████████████████| 393 kB 27.0 MB/s
# ...
#      |████████████████████████████████| 54 kB 300 kB/s
# ...
#      |████████████████████████████████| 77 kB 6.0 MB/s
# ...
#      |████████████████████████████████| 52 kB 1.3 MB/s
# ...
#      |████████████████████████████████| 122 kB 50.0 MB/s
# ...
#      |████████████████████████████████| 122 kB 52.3 MB/s
# ...
#      |████████████████████████████████| 122 kB 37.3 MB/s
# ...
#      |████████████████████████████████| 112 kB 46.8 MB/s
# ...
#      |████████████████████████████████| 56 kB 3.3 MB/s
# ...
#   Created wheel for pyngrok: filename=pyngrok-5.1.0-py3-none-any.whl size=19006 sha256=a2254ca8716df5c1b4bc8ef168d1a2115422307bbfc492129f4545d28309bfe9
# ...

# %%
from colabcode import ColabCode
ColabCode(port=9999)
# Out:
# Code Server can be accessed on: NgrokTunnel: "https://f86c-34-68-200-115.ngrok.io" -> "http://localhost:9999"
# [2021-09-12T21:26:51.223Z] info  code-server 3.10.2 387b12ef4ca404ffd39d84834e1f0776e9e3c005
# [2021-09-12T21:26:51.225Z] info  Using user-data-dir ~/.local/share/code-server
# [2021-09-12T21:26:51.244Z] info  Using config file ~/.config/code-server/config.yaml
# [2021-09-12T21:26:51.244Z] info  HTTP server listening on http://127.0.0.1:9999
# [2021-09-12T21:26:51.245Z] info    - Authentication is disabled
# [2021-09-12T21:26:51.246Z] info    - Not serving HTTPS
#   ERR [File Watcher (chokidar)] Inotify limit reached (ENOSPC)
#   ERR [File Watcher (chokidar)] Inotify limit reached (ENOSPC)
